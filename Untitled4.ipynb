# %% [markdown]
# <a href="https://colab.research.google.com/github/crpytoscooby/College/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/content/dataset_Facebook.csv - dataset_Facebook.csv.csv",sep= ";")

# %%
data.shape
# Out:
# (500, 19)

# %%
data.info
# Out:
# <bound method DataFrame.info of      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
c=data.columns
c
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total,Reach',
#        'Lifetime,Post,Total,Impressions', 'Lifetime,Engaged,Users',
#        'Lifetime,Post,Consumers', 'Lifetime,Post,Consumptions',
#        'Lifetime,Post,Impressions,by,people,who,have,liked,your,Page',
#        'Lifetime,Post,reach,by,people,who,like,your,Page',
#        'Lifetime,People,who,have,liked,your,Page,and,engaged,with,your,post',
#        'comment', 'like', 'share', 'Total,Interactions'],
#       dtype='object')

# %%
sub1 = data[['Page total likes','Type','Category']]
sub2 = data[['Post Month','Post Weekday','Post Hour','Paid']]

# %%
sub1.shape
# Out:
# (500, 3)

# %%
sub2.shape
# Out:
# (500, 4)

# %%
# Merging the subsets created (sub1 and sub2)
merge_data = pd.merge(right=sub1, left=sub2,left_index=True, right_index=True) #  how='left', right_on='Category', left_on='Category')
merge_data
# Out:
#      Post Month  Post Weekday  Post Hour  Paid  Page total likes    Type  \
# 0            12             4          3   0.0            139441   Photo
# 1            12             3         10   0.0            139441  Status
# 2            12             3          3   0.0            139441   Photo
# 3            12             2         10   1.0            139441   Photo
# 4            12             2          3   0.0            139441   Photo
# ..          ...           ...        ...   ...               ...     ...
# 495           1             7          2   0.0             85093   Photo
# 496           1             5          8   0.0             81370   Photo
# 497           1             5          2   0.0             81370   Photo
# 498           1             4         11   0.0             81370   Photo
# 499           1             4          4   NaN             81370   Photo
#
#      Category
# 0           2
# 1           2
# 2           3
# 3           2
# ...

# %%
# Sorting the dataset
sort_data = data.sort_values('Category',ascending=True)
sort_data
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 128            136393  Photo         1          10             6         13
# 144            136013  Photo         1          10             2          3
# 145            136013  Photo         1          10             1         10
# 402            107907  Photo         1           4             3          4
# 401            107907  Photo         1           4             3         13
# ..                ...    ...       ...         ...           ...        ...
# 356            116435  Photo         3           5             1         13
# 359            116091  Photo         3           5             7          2
# 361            116091  Photo         3           5             6          3
# 143            136013  Photo         3          10             2         10
# 162            135617  Photo         3           9             6         10
#
# ...

# %%
# Transposing the dataset (coverting rows to columns and columns to rows)
trans_data = data.transpose()
trans_data
# Out:
#                                                                                            0    \
# Page total likes                                                                        139441
# Type                                                                                     Photo
# Category                                                                                     2
# Post Month                                                                                  12
# Post Weekday                                                                                 4
# Post Hour                                                                                    3
# Paid                                                                                       0.0
# Lifetime Post Total,Reach                                                                 2752
# Lifetime,Post,Total,Impressions                                                           5091
# ...

# %%
# Reshaping the dataset
reshape_data =data.pivot_table(index=['Category','Post Month'])
reshape_data
# Out:
#                      Lifetime Post Total,Reach  Lifetime,Engaged,Users  \
# Category Post Month
# 1        1                        22748.666667              801.666667
#          2                        25634.166667             1514.083333
#          3                        13451.645161             1037.032258
#          4                        29366.818182              892.136364
#          5                        13067.600000              861.800000
#          6                        29405.526316             1078.947368
#          7                        29249.625000             1120.312500
#          8                        15963.444444              938.111111
#          9                        12904.777778              976.555556
#          10                        8981.918919              531.837838
#          11                       17030.969697              519.424242
#          12                       11602.125000              715.812500
# ...

# %%
# Reseting dataset
data.reset_index(drop=True,inplace=True)
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...
