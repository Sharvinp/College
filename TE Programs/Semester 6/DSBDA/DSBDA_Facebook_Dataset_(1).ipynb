# %% [markdown]
# ## DSBDA Assignment 1 (Group B)

# %% [markdown]
# Sharvin Pharande
#
# TE IT
#
# 8022

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("dataset_Facebook.csv", sep=";")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total,Reach                                              0
# Lifetime,Post,Total,Impressions                                        0
# Lifetime,Engaged,Users                                                 0
# Lifetime,Post,Consumers                                                0
# Lifetime,Post,Consumptions                                             0
# Lifetime,Post,Impressions,by,people,who,have,liked,your,Page           0
# ...

# %%
df.Paid.nunique()
# Out:
# 2

# %%
df = df.dropna(subset=["Paid"])

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total,Reach                                              0
# Lifetime,Post,Total,Impressions                                        0
# Lifetime,Engaged,Users                                                 0
# Lifetime,Post,Consumers                                                0
# Lifetime,Post,Consumptions                                             0
# Lifetime,Post,Impressions,by,people,who,have,liked,your,Page           0
# ...

# %%
df = df.fillna(df.mean())
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   0
# Lifetime Post Total,Reach                                              0
# Lifetime,Post,Total,Impressions                                        0
# Lifetime,Engaged,Users                                                 0
# Lifetime,Post,Consumers                                                0
# Lifetime,Post,Consumptions                                             0
# Lifetime,Post,Impressions,by,people,who,have,liked,your,Page           0
# ...

# %%
df.shape
# Out:
# (499, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        499.000000  499.000000   499.00000    499.000000  499.000000
# mean      123277.991984    1.879760     7.05010      4.150301    7.847695
# std        16180.746980    0.853513     3.30016      2.032728    4.369579
# min        81370.000000    1.000000     1.00000      1.000000    1.000000
# 25%       113028.000000    1.000000     4.00000      2.000000    3.000000
# 50%       129600.000000    2.000000     7.00000      4.000000    9.000000
# 75%       136393.000000    3.000000    10.00000      6.000000   11.000000
# max       139441.000000    3.000000    12.00000      7.000000   23.000000
#
#              Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# count  499.000000                 499.000000                     4.990000e+02
# mean     0.278557               13922.829659                     2.963063e+04
# ...

# %% [markdown]
# ## Creating subset by dividing rows

# %%
df_subset_1 = df.loc[250:]
df_subset_1.head()
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 250            129600   Photo         1           7             7          6
# 251            129600   Photo         1           7             6         11
# 252            129600   Photo         3           7             6          5
# 253            129600  Status         2           7             5         12
# 254            129600   Photo         3           7             5          3
#
#      Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 250   1.0                       5848                             9068
# 251   0.0                      26944                            43464
# 252   0.0                       5292                             9321
# 253   1.0                      15576                            27513
# 254   0.0                      54256                            82011
#
#      Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df_subset_1.shape
# Out:
# (249, 19)

# %%
df_subset_2 = df.loc[:249]
df_subset_2.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 245            130791  Photo         1           7             2         13
# 246            130791  Photo         2           7             2          8
# 247            129600  Photo         2           7             1         12
# 248            129600  Photo         3           7             1          6
# 249            129600  Photo         2           7             7         11
#
#      Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 245   0.0                      44464                            66824
# 246   0.0                       2881                             5188
# 247   0.0                       3460                             6503
# 248   0.0                       3406                             5656
# 249   1.0                       2602                             4349
#
#      Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df_subset_2.shape
# Out:
# (250, 19)

# %% [markdown]
# ## Merging 2 subsets row wise

# %%
df_merge_row = pd.concat([df_subset_1, df_subset_2])
df_merge_row
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 250            129600   Photo         1           7             7          6
# 251            129600   Photo         1           7             6         11
# 252            129600   Photo         3           7             6          5
# 253            129600  Status         2           7             5         12
# 254            129600   Photo         3           7             5          3
# ..                ...     ...       ...         ...           ...        ...
# 245            130791   Photo         1           7             2         13
# 246            130791   Photo         2           7             2          8
# 247            129600   Photo         2           7             1         12
# 248            129600   Photo         3           7             1          6
# 249            129600   Photo         2           7             7         11
#
# ...

# %%
df_merge_row.reset_index()
# Out:
#      index  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0      250            129600   Photo         1           7             7
# 1      251            129600   Photo         1           7             6
# 2      252            129600   Photo         3           7             6
# 3      253            129600  Status         2           7             5
# 4      254            129600   Photo         3           7             5
# ..     ...               ...     ...       ...         ...           ...
# 494    245            130791   Photo         1           7             2
# 495    246            130791   Photo         2           7             2
# 496    247            129600   Photo         2           7             1
# 497    248            129600   Photo         3           7             1
# 498    249            129600   Photo         2           7             7
#
#      Post Hour  Paid  Lifetime Post Total,Reach  \
# ...

# %%
df_merge_row.shape
# Out:
# (499, 19)

# %% [markdown]
# ## Creating subset by dividing columns

# %%
df_subset_1 = df.iloc[:,:9]
df_subset_1.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594

# %%
df_subset_1.shape
# Out:
# (499, 9)

# %%
df_subset_2 = df.iloc[:,9:]
df_subset_2.head()
# Out:
#    Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# 0                     178                      109
# 1                    1457                     1361
# 2                     177                      113
# 3                    2211                      790
# 4                     671                      410
#
#    Lifetime,Post,Consumptions  \
# 0                         159
# 1                        1674
# 2                         154
# 3                        1119
# 4                         580
#
#    Lifetime,Post,Impressions,by,people,who,have,liked,your,Page  \
# 0                                               3078
# 1                                              11710
# 2                                               2812
# 3                                              61027
# 4                                               6228
#
#    Lifetime,Post,reach,by,people,who,like,your,Page  \
# 0                                              1640
# ...

# %%
df_subset_2.shape
# Out:
# (499, 10)

# %%
df_merge_col = pd.concat([df_subset_1,df_subset_2],axis=1)
df_merge_col.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df_merge_col.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
#
#      Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 494   0.0                       5400                             9218
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
#
#      Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df_merge_col.shape
# Out:
# (499, 19)

# %% [markdown]
# ## Sorting the dataset

# %%
df_sort = df.sort_values(by=['Lifetime Post Total,Reach'], ascending=True)
df_sort.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 422            102112  Photo         1           3             1         19
# 426            100732  Photo         1           3             7         18
# 432            100732  Photo         1           3             6         17
# 120            136393  Photo         1          10             7          9
# 123            136393  Photo         1          10             7          7
#
#      Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 422   0.0                        238                              570
# 426   0.0                        391                              746
# 432   0.0                        452                              726
# 120   0.0                        584                             1029
# 123   0.0                        617                             1071
#
#      Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %%
df_sort = df.sort_values(by=['Post Hour'], ascending=False)
df_sort.head()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 230            131630  Photo         3           7             2         23
# 287            126141  Photo         1           6             4         22
# 381            109670  Photo         3           4             6         20
# 422            102112  Photo         1           3             1         19
# 426            100732  Photo         1           3             7         18
#
#      Paid  Lifetime Post Total,Reach  Lifetime,Post,Total,Impressions  \
# 230   0.0                       2822                             5058
# 287   1.0                      20560                            24112
# 381   0.0                       5994                             9970
# 422   0.0                        238                              570
# 426   0.0                        391                              746
#
#      Lifetime,Engaged,Users  Lifetime,Post,Consumers  \
# ...

# %% [markdown]
# ## Transpose of the df

# %%
df_transpose = df.T
df_transpose
# Out:
#                                                                                            0    \
# Page total likes                                                                        139441
# Type                                                                                     Photo
# Category                                                                                     2
# Post Month                                                                                  12
# Post Weekday                                                                                 4
# Post Hour                                                                                    3
# Paid                                                                                       0.0
# Lifetime Post Total,Reach                                                                 2752
# Lifetime,Post,Total,Impressions                                                           5091
# ...

# %% [markdown]
# ## Reshape the df

# %%
df_reshape = df.melt(id_vars =['Category', 'Lifetime,Engaged,Users'])
df_reshape
# Out:
#       Category  Lifetime,Engaged,Users            variable  \
# 0            2                     178    Page total likes
# 1            2                    1457    Page total likes
# 2            3                     177    Page total likes
# 3            2                    2211    Page total likes
# 4            2                     671    Page total likes
# ...        ...                     ...                 ...
# 8478         3                     810  Total,Interactions
# 8479         3                     733  Total,Interactions
# 8480         2                     537  Total,Interactions
# 8481         1                     625  Total,Interactions
# 8482         3                     626  Total,Interactions
#
#                                            value
# 0                                         139441
# 1                                         139441
# 2                                         139441
# 3                                         139441
# ...

# %%
col = df[['like','comment','share']]
df_pivot_reshape = pd.pivot_table(col,index=['comment','share'])
df_pivot_reshape
# Out:
#                       like
# comment share
# 0       0.0       2.250000
#         1.0       8.000000
#         2.0      12.090909
#         3.0      20.750000
#         4.0      18.500000
# ...                    ...
# 64      25.0    367.000000
# 103     33.0    469.000000
# 144     208.0  1622.000000
# 146     181.0  1546.000000
# 372     790.0  5172.000000
#
# [317 rows x 1 columns]
